# %% [markdown]
# <a href="https://colab.research.google.com/github/Rheza57/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
from skimage import transform
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening,
                                area_closing, area_opening)
from skimage.color import rgb2gray

# %%
#NOMOR 3
img = cv.imread('/content/drive/MyDrive/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc800ce4a10>,
#  <matplotlib.image.AxesImage at 0x7fc800cd2410>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#NOMOR 4
img1= cv.imread('/content/drive/MyDrive/j.png', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc80073c410>,
#  <matplotlib.image.AxesImage at 0x7fc800690c90>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#NOMOR 5
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc800715310>,
#  <matplotlib.image.AxesImage at 0x7fc800633b90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#NOMOR 6
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc8005bc490>,
#  <matplotlib.image.AxesImage at 0x7fc800586d10>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
#NOMOR 7
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc8004906d0>,
#  <matplotlib.image.AxesImage at 0x7fc800456f50>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
#NOMOR 8
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc8003e4790>,
#  <matplotlib.image.AxesImage at 0x7fc8003f8750>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
#NOMOR 9
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc800332950>,
#  <matplotlib.image.AxesImage at 0x7fc800305210>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc80026db90>,
#  <matplotlib.image.AxesImage at 0x7fc8001d25d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %%
#Nomor 10
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc800153b90>,
#  <matplotlib.image.AxesImage at 0x7fc80011af10>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc80010cf90>,
#  <matplotlib.image.AxesImage at 0x7fc80006d8d0>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 5x5'))

# %%
#Nomor 11
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7fffd4bd0>,
#  <matplotlib.image.AxesImage at 0x7fc7fffc8210>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 3x5'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc8006e6e90>,
#  <matplotlib.image.AxesImage at 0x7fc80055dad0>,
#  Text(0.5, 1.0, 'Citra Hasil Rectangle 5x7'))
